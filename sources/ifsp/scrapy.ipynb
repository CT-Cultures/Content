# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install Scrapy
# !pip install scrapy-user-agents

# %%
path_wd = '/content/drive/MyDrive/Github/Content/sources/ifsp'
path_peek = path_wd + '/peek'

# %%
import os
os.chdir(path_peek)

# %%
# !ls
# Out:
# ifsp

# %%
# Start a project
#!scrapy startproject ifsp
# Out:
# Error: scrapy.cfg already exists in /content/drive/MyDrive/Github/Content/sources/ifsp/peek/ifsp

# %%
# %cd ifsp
# Out:
# /content/drive/My Drive/Github/Content/sources/ifsp/peek/ifsp

# %%
# !scrapy crawl ifsp
# Out:
# 2021-12-17 20:27:53 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: ifsp)
# 2021-12-17 20:27:53 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.7.12 (default, Sep 10 2021, 00:21:48) - [GCC 7.5.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-12-17 20:27:53 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2021-12-17 20:27:53 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'ifsp',
#  'COOKIES_ENABLED': False,
#  'NEWSPIDER_MODULE': 'ifsp.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['ifsp.spiders']}
# 2021-12-17 20:27:53 [scrapy.extensions.telnet] INFO: Telnet Password: c00405c43884e0e2
# 2021-12-17 20:27:53 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...

# %%
# !scrapy shell 'https://www.ifsp.tv/movie'
