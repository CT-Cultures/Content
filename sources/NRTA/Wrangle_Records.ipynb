# %%
import pandas as pd
import numpy as np
import json
import re
import os

# %%
# !pip install pandas==1.3.2

# %%
fp = '/content/drive/MyDrive/Github/Content/sources/NRTA/records/contents_of_registrations.json'

# %%
path_wd = '/content/drive/MyDrive/Github/Content/sources/NRTA/'
os.chdir(path_wd)

# %%
# !python Update_Registration.py

# %%
with open(fp) as file:
  raw = file.read()

# %%
raw[-10:]
# Out:
# '069aa41"}}'

# %%
from Record_Registration import Registration
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-30da98e151d2> in <module>()
# ----> 1 from Record_Registration import Registration
#
# /content/drive/MyDrive/Github/Content/sources/NRTA/Record_Registration.py in <module>()
#      13 import ssl
#      14 #from urllib.error import HTTPError
# ---> 15 from selenium import webdriver
#      16 from bs4 import BeautifulSoup
#      17 import os
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
tv_reg = Registration()

# %%
pd.read_json(raw)

# %%
pd.DataFrame(j2).to_json(fp)
